# %%
saldo = 0
catatan = []

while True:
    print("\n=== Aplikasi Catatan Duit ===")
    print("1. Tambah Pemasukan")
    print("2. Tambah Pengeluaran")
    print("3. Lihat Catatan Transaksi")
    print("4. Cek Saldo")
    print("5. Keluar")

    pilih = input("Pilih menu (1-5): ")

    if pilih == "1":
        duit = int(input("Masukin duit masuk: Rp "))
        keterangan = input("Keterangan: ")
        saldo += duit
        catatan.append(("Masuk", duit, keterangan))

    elif pilih == "2":
        duit = int(input("Masukin duit keluar: Rp "))
        keterangan = input("Keterangan: ")
        saldo -= duit
        catatan.append(("Keluar", duit, keterangan))

    elif pilih == "3":
        print("\n=== Catatan Transaksi ===")
        for jenis, jumlah, ket in catatan:
            print(f"{jenis}: Rp {jumlah} - {ket}")

    elif pilih == "4":
        print(f"\nSaldo sekarang: Rp {saldo}")

    elif pilih == "5":
        print("Sip! Program selesai.")
        break

    else:
        print("Input salah, coba lagi.")
# Out:
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 1
# Masukin duit masuk: Rp 100000000
# Keterangan: gaji
#
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 2
# Masukin duit keluar: Rp 400000
# Keterangan: bayar listrik
#
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 2
# Masukin duit keluar: Rp 300000
# Keterangan: tetangga pinjam duit
#
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 2
# Masukin duit keluar: Rp 500000
# Keterangan: beli make up
#
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 1
# Masukin duit masuk: Rp 300000
# Keterangan: tetangga bayar hutang
#
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 1
# Masukin duit masuk: Rp 50000000
# Keterangan: THR
#
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 3
#
# === Catatan Transaksi ===
# Masuk: Rp 100000000 - gaji
# Keluar: Rp 400000 - bayar listrik
# Keluar: Rp 300000 - tetangga pinjam duit
# Keluar: Rp 500000 - beli make up
# Masuk: Rp 300000 - tetangga bayar hutang
# Masuk: Rp 50000000 - THR
#
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 4
#
# Saldo sekarang: Rp 149100000
#
# === Aplikasi Catatan Duit ===
# 1. Tambah Pemasukan
# 2. Tambah Pengeluaran
# 3. Lihat Catatan Transaksi
# 4. Cek Saldo
# 5. Keluar
# Pilih menu (1-5): 5
# Sip! Program selesai.

# %%
PENGUJIAN APLIKASI CATATAN KEUANGAN

1. Tambah Pemasukan -> Berhasil
2. Tambah Pengeluaran -> Berhasil
3. Lihat Riwayat -> Berhasil
4. Lihat Saldo -> Berhasil
5. Keluar Program -> Berhasil

Evaluasi:
Program berjalan lancar, mudah digunakan, namun data tidak tersimpan saat program ditutup.
